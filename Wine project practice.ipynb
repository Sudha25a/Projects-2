# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Redwine = pd.read_csv("winequality-red.csv", delimiter=';')
Redwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
Whitewine = pd.read_csv("winequality-white.csv", delimiter=';')
Whitewine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
# Redwine and Whitewine quality

sns.set_style('whitegrid')
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 9), sharey=True)
sns.countplot(x='quality', data=Redwine, label='Red Wine', ax=axes[1], color='r')
sns.countplot(x='quality', data=Whitewine, label='White Wine', ax=axes[0], color='g')
axes[1].set_title('Red Wine Quality', alpha=0.8)
axes[0].set_title('White Wine Quality', alpha=0.8)

plt.show()

# %%
plt.figure(figsize=(12,8))
corr_matrix = Whitewine.corr()
sns.heatmap(corr_matrix, cmap='coolwarm',annot=True, square=True)
# Out:
# <Axes: >

# %%
# Create a correlation matrix for red wine features
plt.figure(figsize=(12,8))
corr_matrix= Whitewine.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True, mask=mask)
plt.title('White Wine Correlation Matrix')

plt.show()

# %%
plt.figure(figsize=(12,8))
corr_matrix = Redwine.corr()
sns.heatmap(corr_matrix, cmap='coolwarm',annot=True, square=True)
# Out:
# <Axes: >

# %%
# Create a correlation matrix for red wine features
plt.figure(figsize=(12,8))
corr_matrix_red = Redwine.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix_red, dtype=bool))
sns.heatmap(corr_matrix_red, annot=True, cmap='coolwarm', square=True, mask=mask)
plt.title('Red Wine Correlation Matrix')
plt.show()

# %%
# Create a scatter plot to visualize the relationship between pH and fixed acidity
plt.figure(figsize=(10,6))
sns.scatterplot(x='pH', y='fixed acidity', data=Redwine, label='Red Wine', color ='r')
sns.scatterplot(x='pH', y='fixed acidity', data=Whitewine, label='White Wine', color = 'g')
plt.title('Relationship between pH and Acidity')
plt.xlabel('pH')
plt.ylabel('fixed acidity')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='alcohol', y='density', data=Redwine, label='Red Wine', color ='r')
plt.title('Relationship between Alcohol and Density')
plt.xlabel('Alcohol')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='alcohol', y='density', data=Whitewine, label='White Wine', color='g')
plt.title('Relationship between Alcohol and Density')
plt.xlabel('Alcohol')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
# Create a correlation matrix for red wine features
plt.figure(figsize=(10,8))
corr_matrix_red = Redwine.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix_red, dtype=bool))
sns.heatmap(corr_matrix_red, annot=True, cmap='coolwarm', square=True, mask=mask)
plt.title('Red Wine Correlation Matrix')
plt.show()

# %%
# Create a histogram of acidity levels
plt.hist(Redwine['fixed acidity'], label='Red Wine', color= 'r', alpha=0.8)
plt.hist(Whitewine['fixed acidity'], label='White Wine',color='g', alpha=0.8)
plt.title('Comparative Acidity Analysis')
plt.xlabel('Acidity Level')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
sns.set_style('whitegrid')
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 9), sharey=True)
sns.countplot(x= 'fixed acidity', data=Redwine, label='Red Wine', ax=axes[1], color='r')
sns.countplot(x='fixed acidity', data=Whitewine, label='White Wine', ax=axes[0], color='g')
axes[1].set_title('Red Wine Quality', alpha=0.8)
axes[0].set_title('White Wine Quality', alpha=0.8)
plt.show()

# %%
# Create a box plot to compare the distribution of fixed acidity in red and white wines
plt.figure(figsize=(10,6))
sns.boxplot(x='wine_type', y='fixed acidity', data=pd.concat([Redwine.assign(wine_type='Red'), Whitewine.assign(wine_type='White',  palette="dark")]))
plt.title('Comparison of Acidity Distribution')
plt.xlabel('Wine Type')
plt.ylabel('Acidity')
plt.show()

# %%
# Create a violin plot to compare the distribution of pH in red and white wines
plt.figure(figsize=(12,8))
sns.catplot(x='wine_type', y='pH', data=pd.concat([Redwine.assign(wine_type='Red'), Whitewine.assign(wine_type='White')]))
plt.title('Comparison of pH Distribution')
plt.xlabel('Wine Type')
plt.ylabel('pH')
plt.show()

# %%
# Density Plot of residual sugar
variable = 'residual sugar'
sns.kdeplot(Redwine[variable])
sns.kdeplot(Whitewine[variable])
plt.title(f'Density Plot of {variable}')
plt.xlabel(variable)
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
# Create a count plot to compare the quality of red and white wines
sns.set_style('whitegrid')
fig, axes=plt.subplots(nrows=1,ncols=2,figsize = (15,9))
sns.countplot(x='quality', data=Redwine, label='Red Wine', ax= axes[0], color='r')
sns.countplot(x='quality', data=Whitewine, label='White Wine',ax=axes[1], color='.2')
axes[0].set_title('RedWine Quality', alpha=0.8)
axes[1].set_title('WhiteWine Quality', alpha=0.8)
# Out:
# Text(0.5, 1.0, 'WhiteWine Quality')

# %%
# wine_data = pd.concat([Redwine, Whitewine])
# wine_data.fillna(wine_data.mean(), inplace=True)
# wine_data

# %%
Redwine.hist(bins=25,figsize=(8,8), color='r')
plt.show()

# %%
Whitewine.hist(bins=25,figsize=(8,8), color=".2")
plt.show()

# %%
# Create a scatter plot of alcohol content vs. quality
plt.figure(figsize=(10,6))
plt.scatter(Redwine['alcohol'], Redwine['quality'], label='Red Wine', color ='r')
plt.scatter(Whitewine['alcohol'], Whitewine['quality'], label='White Wine', color ='g')
plt.title('Alcohol content vs Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Quality')
plt.legend()
plt.show()

# %%
# Create a scatter plot of alcohol content vs. quality
plt.figure(figsize=(10,6))
plt.scatter(Redwine['alcohol'], Redwine['quality'], label='Red Wine', color ='r')
plt.title('Redwine Alcohol content vs Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Quality')
plt.legend()
plt.show()

# %%
# Create a scatter plot of alcohol content vs. quality
plt.figure(figsize=(6,6))
plt.scatter(Whitewine['quality'], Whitewine['alcohol'], label='White Wine', color ='g')
plt.title('Whitewine Alcohol content vs Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Quality')
plt.legend()
plt.show()

# %%
# plt.figure(figsize=(10,6))
# plt.plot(Redwine['alcohol'], Redwine['quality'], label='Red Wine', marker='o', color='r')
# plt.plot(Whitewine['alcohol'], Whitewine['quality'], label='White Wine', marker='o', color ='g')
# plt.title('Alcohol content vs Quality')
# plt.xlabel('Alcohol Content')
# plt.ylabel('Quality')
# plt.legend()
# plt.show()

# %%
# plt.figure(figsize=(10,6))
# plt.plot(Redwine['alcohol'], Redwine['quality'], label='Red Wine', marker='o', color='r')
# plt.title('Redwine Alcohol content vs Quality')
# plt.xlabel('Alcohol Content')
# plt.ylabel('Quality')
# plt.legend()
# plt.show()

# %%
# plt.figure(figsize=(10,6))
# plt.plot(Whitewine['alcohol'], Whitewine['quality'], label='White Wine', marker='o', color ='g')
# plt.title('Whitewine Alcohol content vs Quality')
# plt.xlabel('Alcohol Content')
# plt.ylabel('Quality')
# plt.legend()
# plt.show()

# %%
# Plot the responses for different events and regions
sns.lineplot(x="pH", y="alcohol",data=Redwine)
# Out:
# <Axes: xlabel='pH', ylabel='alcohol'>

# %%
sns.relplot(data= Redwine, x= 'pH', y= 'density')

# %%
sns.set_theme(style="whitegrid")

sns.residplot(data= Redwine, x= 'density', y= 'alcohol', lowess=True, color="g")
# Out:
# <Axes: xlabel='density', ylabel='alcohol'>

# %%
sns.set_theme(style="ticks")
sns.jointplot(data = Redwine, x= 'fixed acidity', y='alcohol', kind="hex", color="#4CB391")

# %%
Redwine.sample(25)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 346             6.6             0.815         0.02             2.7      0.072
# 1394            6.4             0.570         0.14             3.9      0.070
# 1451            7.8             0.320         0.44             2.7      0.104
# 1533            8.0             0.390         0.30             1.9      0.074
# 839             6.0             0.500         0.04             2.2      0.092
# 1369            6.6             0.610         0.00             1.6      0.069
# 742             6.5             0.615         0.00             1.9      0.065
# 861             5.8             1.010         0.66             2.0      0.039
# 966             9.0             0.380         0.41             2.4      0.103
# 1253            7.9             0.660         0.00             1.4      0.096
# 411             9.1             0.450         0.35             2.4      0.080
# 760             9.0             0.580         0.25             2.8      0.075
# 957             9.5             0.370         0.52             2.0      0.088
# 1339            7.5             0.510         0.02             1.7      0.084
# 512            10.7             0.400         0.48             2.1      0.125
# 1174            7.6             0.360         0.31             1.7      0.079
# 575            12.3             0.270         0.49             3.1      0.079
# 181             8.9             0.610         0.49             2.0      0.270
# 392             9.5             0.370         0.52             2.0      0.082
# 190             8.2             0.500         0.35             2.9      0.077
# 1448            6.9             0.580         0.01             1.9      0.080
# 878             8.8             0.610         0.19             4.0      0.094
# 1232            7.6             0.430         0.29             2.1      0.075
# 632             7.6             0.410         0.14             3.0      0.087
# 42              7.5             0.490         0.20             2.6      0.332
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 346                  17.0                  34.0  0.99550  3.58       0.89
# 1394                 27.0                  73.0  0.99669  3.32       0.48
# 1451                  8.0                  17.0  0.99732  3.33       0.78
# 1533                 32.0                  84.0  0.99717  3.39       0.61
# 839                  13.0                  26.0  0.99647  3.46       0.47
# 1369                  4.0                   8.0  0.99396  3.33       0.37
# 742                   9.0                  18.0  0.99720  3.46       0.65
# 861                  15.0                  88.0  0.99357  3.66       0.60
# 966                   6.0                  10.0  0.99604  3.13       0.58
# 1253                  6.0                  13.0  0.99569  3.43       0.58
# 411                  23.0                  78.0  0.99870  3.38       0.62
# 760                   9.0                 104.0  0.99779  3.23       0.57
# 957                  12.0                  51.0  0.99613  3.29       0.58
# 1339                 13.0                  31.0  0.99538  3.36       0.54
# 512                  15.0                  49.0  0.99800  3.03       0.81
# 1174                 26.0                  65.0  0.99716  3.46       0.62
# 575                  28.0                  46.0  0.99930  3.20       0.80
# 181                  23.0                 110.0  0.99720  3.12       1.02
# 392                   6.0                  26.0  0.99800  3.18       0.51
# 190                  21.0                 127.0  0.99760  3.23       0.62
# 1448                 40.0                  54.0  0.99683  3.40       0.73
# 878                  30.0                  69.0  0.99787  3.22       0.50
# 1232                 19.0                  66.0  0.99718  3.40       0.64
# 632                  21.0                  43.0  0.99640  3.32       0.57
# 42                    8.0                  14.0  0.99680  3.21       0.90
#
#       alcohol  quality
# 346      12.3        7
# 1394      9.2        5
# 1451     11.0        7
# 1533      9.0        5
# 839      10.0        5
# 1369     10.4        4
# 742       9.2        5
# 861      11.5        6
# 966      11.9        7
# 1253      9.5        5
# 411       9.5        5
# 760       9.7        5
# 957      11.1        6
# 1339     10.5        6
# 512       9.7        6
# 1174      9.5        6
# 575      10.2        6
# 181       9.3        5
# 392       9.5        5
# 190       9.4        5
# 1448      9.7        5
# 878      10.0        6
# 1232      9.5        5
# 632      10.5        6
# 42       10.5        6

# %%
Redwine.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# 8         0.068444            13.277778             33.444444  0.995212
#
#                pH  sulphates    alcohol
# quality
# 3        3.398000   0.570000   9.955000
# 4        3.381509   0.596415  10.265094
# 5        3.304949   0.620969   9.899706
# 6        3.318072   0.675329  10.629519
# 7        3.290754   0.741256  11.465913
# 8        3.267222   0.767778  12.094444

# %%
Redwine['fixed acidity'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# quality_bins = [0, 6, 7, 10]  # Adjust these bins as needed
quality_labels = ['low', 'medium', 'high']
Winedata['quality_bin'] = pd.cut(Winedata['quality'], bins=quality_bins, labels=quality_labels)
sns.scatterplot(x='alcohol', y='sulphates', hue='quality_bin', data=wine_data, palette=['gold', 'orange', 'navy'], alpha=0.5)
plt.title('Red Wines - Sulphates, Alcohol and Quality')
plt.legend(title='Quality')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 # quality_bins = [0, 6, 7, 10]  # Adjust these bins as needed
#       2 quality_labels = ['low', 'medium', 'high']
# ----> 3 Winedata['quality_bin'] = pd.cut(Winedata['quality'], bins=quality_bins, labels=quality_labels)
#       4 sns.scatterplot(x='alcohol', y='sulphates', hue='quality_bin', data=wine_data, palette=['gold', 'orange', 'navy'], alpha=0.5)
#       5 plt.title('Red Wines - Sulphates, Alcohol and Quality')
#
# NameError: name 'Winedata' is not defined
