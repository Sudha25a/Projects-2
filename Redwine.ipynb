# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
Redwine = pd.read_csv("winequality-red.csv", delimiter=';')
Redwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
Redwine.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 197            11.5             0.300         0.60             2.0      0.067
# 85              6.9             0.550         0.15             2.2      0.076
# 1355            6.1             0.320         0.25             1.8      0.086
# 1582            6.1             0.715         0.10             2.6      0.053
# 471             9.6             0.540         0.42             2.4      0.081
# 1255            6.1             0.640         0.02             2.4      0.069
# 683             8.1             0.780         0.23             2.6      0.059
# 1169            7.6             0.500         0.29             2.3      0.086
# 1354            7.2             0.580         0.03             2.3      0.077
# 863             7.2             0.620         0.06             2.5      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
Redwine.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
Redwine['fixed acidity'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
Redwine['quality'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# Redwine['fixed acidity'].plot(kind = 'box')
sns.boxplot(data= Redwine, x='pH')
# Out:
# <Axes: xlabel='pH'>

# %%
Redwine.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
# Create a correlation matrix for red wine features
plt.figure(figsize=(12,8))
corr_matrix_red = Redwine.corr()

# Create a mask for the upper triangle
# mask = np.triu(np.ones_like(corr_matrix_red, dtype=bool))
sns.heatmap(corr_matrix_red, annot=True, cmap='coolwarm', square=True)
# mask=mask
plt.title('Red Wine Correlation Matrix')
plt.show()

# %%
plt.scatter(data=Redwine, x= 'alcohol', y = 'quality', label='Red Wine', color= 'r')

# %%
#  Plot 1: Red wine pH vs. acidity
sns.scatterplot(x='pH', y='fixed acidity', data=Redwine)
# Out:
# <Axes: xlabel='pH', ylabel='fixed acidity'>

# %%
# Red wine sugar content distribution
sns.histplot(x='residual sugar', data=Redwine)
# Out:
# <Axes: xlabel='residual sugar', ylabel='Count'>
