# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.plot()
plt.show()

# %%
fig = plt.figure(figsize=[7,4], facecolor='b')
# fig = plt.figure(figsize=[7,4], facecolor='c'), layout='tight'
plt.plot()
plt.show()

# %%
plt.title("Example Table", fontweight='bold', fontsize='x-large', pad=12)
plt.xlabel(" x label", fontweight='bold')
plt.ylabel(" y label", fontweight='bold')

plt.plot()
plt.show()
