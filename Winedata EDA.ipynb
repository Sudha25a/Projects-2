# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# import sklearn as sk
Redwine = pd.read_csv("winequality-red.csv", delimiter=';')
Whitewine = pd.read_csv("winequality-white.csv", delimiter=';')

# %%
Whitewine.shape
# Out:
# (4898, 12)

# %%
Redwine.shape
# Out:
# (1599, 12)

# %%
red_value = ['red']
Redwine['type'] = red_value * 1599
white_value = ['white']
Whitewine ['type'] =white_value * 4898

# %%
Redwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
Whitewine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
Winedata = pd.concat([Redwine, Whitewine])
Winedata
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
string_col = Winedata.select_dtypes(include="object").columns

# %%
Winedata[string_col].head()
# Out:
#   type
# 0  red
# 1  red
# 2  red
# 3  red
# 4  red

# %%
for col in string_col:
    print(f"The distribution of categorical values in the {col} is : ")
    print(Winedata[col].value_counts())
# Out:
# The distribution of categorical values in the type is :
# type
# white    4898
# red      1599
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(Winedata['type'])
plt.title('Wine Type')
plt.show()

# %%
sns.countplot(data=Winedata,x='quality')
plt.title('Quality of wine')
# Out:
# Text(0.5, 1.0, 'Quality of wine')

# %%
X = Winedata.drop(columns=['type', 'quality'])
y = Winedata['quality']

# %%
y.value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
# from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.model_selection import cross_val_score, train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
dfm = Winedata.copy()

# %%
cat_cols = dfm.select_dtypes('object')
for label, values in cat_cols.items():
    print(label, values.unique())
# Out:
# type ['red' 'white']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
dfm['quality'] = le.fit_transform(dfm['quality'])
dfm['quality'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    3
# 4    2
# Name: quality, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=47)

# %%
from sklearn.linear_model import LogisticRegression

LR_model = LogisticRegression(max_iter=1000)

# %%
LR_model.fit(X_train, y_train)
# Out:
# c:\Users\meeta\anaconda3\envs\CodeAcadamyBerlinCAB\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
preds = LR_model.predict(X_test)
preds
# Out:
# array([6, 6, 6, ..., 5, 6, 5], dtype=int64)

# %%
y_test
# Out:
# 3153    6
# 2935    4
# 4583    6
# 3625    5
# 965     6
#        ..
# 1414    6
# 2212    6
# 638     7
# 1298    6
# 2678    5
# Name: quality, Length: 1300, dtype: int64

# %%
from sklearn.metrics import accuracy_score 

acc = accuracy_score(y_test, preds)
acc
# Out:
# 0.5330769230769231
